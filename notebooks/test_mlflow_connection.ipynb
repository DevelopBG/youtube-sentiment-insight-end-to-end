# %%
import mlflow

mlflow.set_tracking_uri("http://15.135.159.216:5000/")
mlflow.set_experiment("my-experiment")

with mlflow.start_run():
    mlflow.log_param('hi', 0.7)
    mlflow.log_metric("metric", 0.98)
# Out:
# 2026/02/25 18:09:14 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment' does not exist. Creating a new experiment.
